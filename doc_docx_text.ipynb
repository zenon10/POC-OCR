# %% [markdown]
# <a href="https://colab.research.google.com/github/zenon10/POC-OCR/blob/main/doc_docx_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/zenon10/POC-OCR
# Out:
# fatal: destination path 'POC-OCR' already exists and is not an empty directory.

# %% [markdown]
# ##textract

# %%
# !apt-get install python-dev libxml2-dev libxslt1-dev antiword unrtf poppler-utils \
     pstotext tesseract-ocr \
     flac ffmpeg lame libmad0 libsox-fmt-mp3 sox libjpeg-dev swig libasound2-dev libpulse-dev
# !pip install git+https://github.com/deanmalmgren/textract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'python-dev-is-python2' instead of 'python-dev'
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libasound2-dev is already the newest version (1.2.2-2.1ubuntu2.5).
# libxml2-dev is already the newest version (2.9.10+dfsg-5ubuntu0.20.04.5).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript
#   libblkid-dev libffi-dev libglib2.0-dev libglib2.0-dev-bin libgs9
#   libgs9-common libid3tag0 libidn11 libijs-0.35 libjbig2dec0 libmagic-mgc
#   libmagic1 libmount-dev libopencore-amrnb0 libopencore-amrwb0 libpython2-dev
# ...

# %%
import textract
from bs4 import BeautifulSoup

# %% [markdown]
# ### Docx

# %%
docx_text = textract.process("/content/POC-OCR/raw_data/french/f2.docx") 
docx_text
# Out:
# b'Tableau 4.2\n\n\xc2\xa0\n\nAMENDEMENT N\xc2\xb0 1 \xc3\x80 LA CONVENTION D\xe2\x80\x99ACHAT D\xe2\x80\x99ACTIONS ET D\xe2\x80\x99ACTIFS\n\n\xc2\xa0\n\nLe pr\xc3\xa9sent premier amendement \xc3\xa0 la convention d\xe2\x80\x99achat d\xe2\x80\x99actions et d\xe2\x80\x99actifs, dat\xc3\xa9 du 27 d\xc3\xa9cembre 2013 (le \xc2\xab premier amendement \xc2\xbb), est conclu par et entre  Novartis Vaccines and Diagnostics, Inc., une soci\xc3\xa9t\xc3\xa9 du Delaware (\xc2\xab Vendeur \xc2\xbb), Novartis Corporation, une soci\xc3\xa9t\xc3\xa9 de New York, en tant que garant, G-C Diagnostics Corp., une soci\xc3\xa9t\xc3\xa9 du Delaware (\xc2\xab Acheteur \xc2\xbb), et Grifols, S.A. une soci\xc3\xa9t\xc3\xa9 (sociedad an\xc3\xb3nima ) organis\xc3\xa9e en vertu des lois espagnoles, en qualit\xc3\xa9 de garant.\n\n\xc2\xa0\n\nCONSID\xc3\x89RANTS\n\n\xc2\xa0\n\nATTENDU QUE les parties aux pr\xc3\xa9sentes sont parties \xc3\xa0 cette convention d\xe2\x80\x99achat d\xe2\x80\x99actions et d\xe2\x80\x
# ...

# %%
soup = BeautifulSoup(docx_text)
print(soup.get_text())
# Out:
# Tableau 4.2
#
#
#
# AMENDEMENT N° 1 À LA CONVENTION D’ACHAT D’ACTIONS ET D’ACTIFS
#
#
#
# Le présent premier amendement à la convention d’achat d’actions et d’actifs, daté du 27 décembre 2013 (le « premier amendement »), est conclu par et entre  Novartis Vaccines and Diagnostics, Inc., une société du Delaware (« Vendeur »), Novartis Corporation, une société de New York, en tant que garant, G-C Diagnostics Corp., une société du Delaware (« Acheteur »), et Grifols, S.A. une société (sociedad anónima ) organisée en vertu des lois espagnoles, en qualité de garant.
#
#
#
# CONSIDÉRANTS
#
#
#
# ATTENDU QUE les parties aux présentes sont parties à cette convention d’achat d’actions et d’actifs datée du 10 novembre 2013 (la « convention originale ») et souhaitent amender et modifier certaines modalités de la convention originale telles que spécifiées dans le présent premier amendement; et
#
#
#
# ...

# %% [markdown]
# ### Doc

# %%
doc_text = textract.process("/content/POC-OCR/raw_data/french/f2.doc") 
doc_text
# Out:
# b'\n                                                                 Tableau 4.2\n                                      \xc2\xa0\n        AMENDEMENT N\xc2\xb0 1 \xc3\x80 LA CONVENTION D\xe2\x80\x99ACHAT D\xe2\x80\x99ACTIONS ET D\xe2\x80\x99ACTIFS\n                                      \xc2\xa0\nLe pr\xc3\xa9sent premier amendement \xc3\xa0 la convention d\xe2\x80\x99achat d\xe2\x80\x99actions et\nd\xe2\x80\x99actifs, dat\xc3\xa9 du 27 d\xc3\xa9cembre 2013 (le \xc2\xab premier amendement \xc2\xbb), est conclu\npar et entre  Novartis Vaccines and Diagnostics, Inc., une soci\xc3\xa9t\xc3\xa9 du\nDelaware (\xc2\xab Vendeur \xc2\xbb), Novartis Corporation, une soci\xc3\xa9t\xc3\xa9 de New York, en\ntant que garant, G-C Diagnostics Corp., une soci\xc3\xa9t\xc3\xa9 du Delaware (\xc2\xab Acheteur\n\xc2\xbb), et Grifols, S.A. une soci\xc3\xa9t\xc3\xa9 (sociedad an\xc3\xb3nima ) organis\xc3\xa9e en vertu des\nlois espagnoles, en qualit\xc3\xa9 de garant.\n\xc2\xa0\n                            
# ...

# %%
soup = BeautifulSoup(doc_text)
print(soup.get_text())
# Out:
# Tableau 4.2
#
#         AMENDEMENT N° 1 À LA CONVENTION D’ACHAT D’ACTIONS ET D’ACTIFS
#
# Le présent premier amendement à la convention d’achat d’actions et
# d’actifs, daté du 27 décembre 2013 (le « premier amendement »), est conclu
# par et entre  Novartis Vaccines and Diagnostics, Inc., une société du
# Delaware (« Vendeur »), Novartis Corporation, une société de New York, en
# tant que garant, G-C Diagnostics Corp., une société du Delaware (« Acheteur
# »), et Grifols, S.A. une société (sociedad anónima ) organisée en vertu des
# lois espagnoles, en qualité de garant.
#
#                                 CONSIDÉRANTS
#
# ATTENDU QUE les parties aux présentes sont parties à cette convention
# d’achat d’actions et d’actifs datée du 10 novembre 2013 (la « convention
# originale ») et souhaitent amender et modifier certaines modalités de la
# convention originale telles que spécifiées dans le présent premier
# amendement; et
#
# ...

# %% [markdown]
# ### excel

# %%
excel_text = textract.process("f2.xlsx") 
excel_text
# Out:
# b'\nTableau 4.2\nAMENDEMENT N\xc2\xb0  1A LA CONVENTION  D\'ACHAT D\'ACTIONS ET D\'ACTIFS\nLe present premier amendement a la convention d \'achat d\'actions et d\'actif s, date du 27 decembre 2013 (le \xc2\xab premier amendement  \xc2\xbb), est conclu par et entre  Novartis Vaccines and Diagnostics, Inc., une societe du Delaware (\xc2\xab Vendeur  \xc2\xbb), Novartis Corporation , une societe de New York, en tant que garant, G-C Diagnostics Corp., une societe du Delaware (\xc2\xab Acheteur  \xc2\xbb), et Grifols, S.A. une societe ( sociedad an6nima ) organisee en vertu des lois espagnoles, en qualite de garant.\nCONSIDERANTS\nATTENDU QUE les parties aux presentes sont parties a cette convention d \'achat d\'actions et d\'actifs datee du 10 novembre 2013 (la \xc2\xab convention originale \xc2\xbb) et souhaitent amender et modifier certaines modalites de la convention originale telles que specifiees dans le present premier amendement; et\nATTENDU QUE l\'article 10.10 de l\'entente ori
# ...

# %%
soup = BeautifulSoup(excel_text)
print(soup.get_text())
# Out:
# Tableau 4.2
# AMENDEMENT N°  1A LA CONVENTION  D'ACHAT D'ACTIONS ET D'ACTIFS
# Le present premier amendement a la convention d 'achat d'actions et d'actif s, date du 27 decembre 2013 (le « premier amendement  »), est conclu par et entre  Novartis Vaccines and Diagnostics, Inc., une societe du Delaware (« Vendeur  »), Novartis Corporation , une societe de New York, en tant que garant, G-C Diagnostics Corp., une societe du Delaware (« Acheteur  »), et Grifols, S.A. une societe ( sociedad an6nima ) organisee en vertu des lois espagnoles, en qualite de garant.
# CONSIDERANTS
# ATTENDU QUE les parties aux presentes sont parties a cette convention d 'achat d'actions et d'actifs datee du 10 novembre 2013 (la « convention originale ») et souhaitent amender et modifier certaines modalites de la convention originale telles que specifiees dans le present premier amendement; et
# ...
